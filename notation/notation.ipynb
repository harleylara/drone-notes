# %%
from IPython.display import display, HTML, Javascript, IFrame, Latex

Latex(filename="./notation.tex")
# Out:
# \input{commands.tex}
#
# % Bold symbol definition
# $
# \newcommand{\bm}[1]{{\boldsymbol #1}}
# $
#
# % Vectors
# $
# \def\vzero{{\bm{0}}}
# \def\vone{{\bm{1}}}
# \def\vmu{{\bm{\mu}}}
# \def\vtheta{{\bm{\theta}}}
# \def\va{{\bm{a}}}
# \def\vb{{\bm{b}}}
# \def\vc{{\bm{c}}}
# \def\vd{{\bm{d}}}
# \def\ve{{\bm{e}}}
# \def\vf{{\bm{f}}}
# \def\vg{{\bm{g}}}
# \def\vh{{\bm{h}}}
# \def\vi{{\bm{i}}}
# \def\vj{{\bm{j}}}
# \def\vk{{\bm{k}}}
# \def\vl{{\bm{l}}}
# \def\vm{{\bm{m}}}
# \def\vn{{\bm{n}}}
# \def\vo{{\bm{o}}}
# \def\vp{{\bm{p}}}
# \def\vq{{\bm{q}}}
# \def\vr{{\bm{r}}}
# \def\vs{{\bm{s}}}
# \def\vt{{\bm{t}}}
# \def\vu{{\bm{u}}}
# \def\vv{{\bm{v}}}
# \def\vw{{\bm{w}}}
# \def\vx{{\bm{x}}}
# \def\vy{{\bm{y}}}
# \def\vz{{\bm{z}}}
# $
#
# % Elements of vectors
# $
# \def\evalpha{{\alpha}}
# \def\evbeta{{\beta}}
# \def\evepsilon{{\epsilon}}
# \def\evlambda{{\lambda}}
# \def\evomega{{\omega}}
# \def\evmu{{\mu}}
# \def\evpsi{{\psi}}
# \def\evsigma{{\sigma}}
# \def\evtheta{{\theta}}
# ...

# %% [markdown]
# # Notation

# %% [markdown]
# | | |
# |---|---|
# | $a$ | scalar $\in \sR$ |
# | $\va$ | vector $\in \sR^n$ |
# | $\mA$ | matrix $\in \sR^{m \times n}$|
# | $\sR$ | set of ... |
# | $\mI$ | identity matrix |
# | $\mA^\transpose$ | matrix transpose |
# | $\ava$ | aumented vector |
# | $\hcx, \hcy, \hcw$ | homogeneous coordinates |
# | $\hva$ | homogeneous vector |
# | $\nsa$ | normal scalar |
# | $\nva$ | normal vector |
#
#
# | | |
# |---|---|
# | $\rfA$ | reference frame |
# | $\roll$ | roll |
# | $\pitch$ | pitch |
# | $\yaw$ | yaw |
